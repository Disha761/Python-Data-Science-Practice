# %%
#Import NumPy and Pandas.
import numpy as np 
import pandas as pd

# %%
#Load the CSV into a DataFrame named df.
df = pd.read_csv(r'order_detail_utf8.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#Display the first 5 rows.
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#Find the number of rows and columns.
df.shape
# Out:
# (9994, 21)

# %%
#Display all column names.
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Check the data types of every column.
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#Check how much memory the DataFrame uses.
df.memory_usage().sum()
# Out:
# np.int64(1679120)

# %%
#Find the number of missing (NaN) values in every column.
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# #duplicate

# %%
#Check whether your dataset contains duplicate rows.
df.duplicated()
#Number of duplicate rows
df.duplicated().sum()
#Remove the duplicates only if they exist
df = df.drop_duplicates()
#Find the basic statistical summary of all numerical columns.
df['Sales'].agg(['count','mean','std','min','max'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %% [markdown]
# #unique value

# %%
#number of unique values
df.nunique()
df.nunique() < len(df)
df.nunique() == len(df)
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
#TOTAL SALES
total_sales = df['Sales'].sum()
total_sales
#AVG SALES PER ORDER/ROE
df['Sales'].mean()
#TOTAL PROFIT
total_profit = df['Profit'].sum()
total_profit
#AVG PROFIT
df['Profit'].mean()
#TOTAL QUANTITY SOLED
df['Quantity'].sum()
#OVERALL PROFIT MARGIN 
profit_margin = (total_profit/total_sales)*100
profit_margin
# Out:
# np.float64(12.467217240315604)

# %% [markdown]
# #Which product Category generates the most Sales and Profit?

# %%
#Total Sales
ts = df.groupby('Category')['Sales'].sum()
#2. Total Profit by Category
tp = df.groupby('Category')['Profit'].sum()
#3️ Average Sales by Category
avs = df.groupby('Category')['Sales'].mean()
#️Average Profit by Category
avp = df.groupby('Category')['Profit'].mean()

# %% [markdown]
# level 4

# %%
# Average Discount for each Category
df.groupby('Category')['Discount'].mean()
# Average Profit for each Category
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
# Correlation between Discount and Profit
df['Discount'].corr(df['Profit'])
# Out:
# np.float64(-0.21948745637176834)

# %% [markdown]
# Scatter Plot

# %%
#X-axis: Discount
#y-axis: Profit
#Title: Discount vs Profit

# %%
import matplotlib.pyplot as plt

# %%
x = df['Discount']
x
y = df['Profit']
y
plt.scatter(x,y)
plt.title("Discount vs Profit")
plt.ylabel("Profit")
plt.xlabel("Discount")
# Out:
# Text(0.5, 0, 'Discount')

# %% [markdown]
# **Task 6 — Sales by Region**

# %%
#Find total Sales and Profit for each Region. 
x = df.groupby("Region")["Sales"].sum()
x
y = df.groupby("Region")["Profit"].sum()
y

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Identify the best and worst region by profit.
y.idxmax()
y.idxmin()
# Out:
# 'Central'

# %% [markdown]
# Task 7 — Segment Analysis

# %%
#Total Sales
x = df.groupby('Segment')['Sales'].sum()
#Total Profit
y = df.groupby('Segment')['Profit'].sum()
#Average Profit
df.groupby('Segment')['Profit'].mean()
# Out:
# Segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: Profit, dtype: float64

# %%
# Most profitable segment
y.idxmax()
#Highest-sales segment
x.idxmax()
# Out:
# 'Consumer'

# %% [markdown]
# 🔥 Task 8 — Sub-Category Analysis

# %%
#Top 5 Sub-Categories by Total Profit
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Name: Profit, dtype: float64

# %%
#Bottom 5 Sub-Categories by Total Profit
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=True).head(5)
# Out:
# Sub-Category
# Tables      -17725.4811
# Bookcases    -3472.5560
# Supplies     -1189.0995
# Fasteners      949.5182
# Machines      3384.7569
# Name: Profit, dtype: float64

# %% [markdown]
# Task 9 — Top 10 Products by Sales

# %%
#Product Name ke according total Sales calculate karo.
df.groupby('Product Name')['Sales'].sum()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                     25.228
# #10 Gummed Flap White Envelopes, 100/Box                                                                 41.300
# #10 Self-Seal White Envelopes                                                                           108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                              488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                 286.672
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4     477.660
# iOttie HLCRIO102 Car Mount                                                                              215.892
# ...

# %%
#Top 10 products by total Sales find karo.
df.groupby('Product Name')['Sales'].sum().sort_values(ascending = False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# 🔥 Task 10 — Loss-Making Products

# %%
#Kaunse products overall loss mein hain?
p_p = df.groupby('Product Name')['Profit'].sum()

# %%
p_p[p_p<0]
# Out:
# Product Name
# 3.6 Cubic Foot Counter Height Office Refrigerator                 -872.0752
# 36X48 HARDFLOOR CHAIRMAT                                           -40.4914
# 3D Systems Cube Printer, 2nd Generation, White                    -467.9964
# 3M Replacement Filter for Office Air Cleaner for 20' x 33' Room    -20.4768
# ARKON Windshield Dashboard Air Vent Car Mount Holder               -15.5940
#                                                                      ...
# XtraLife ClearVue Slant-D Ring Binders by Cardinal                 -13.3280
# Zebra GK420t Direct Thermal/Thermal Transfer Printer              -938.2800
# i.Sound Portable Power - 8000 mAh                                  -58.8189
# iOttie HLCRIO102 Car Mount                                         -11.9940
# iOttie XL Car Mount                                                -50.3748
# Name: Profit, Length: 301, dtype: float64

# %%
p_p[p_p < 0].sort_values(ascending=True).head(10)
# Out:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                           -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                           -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                           -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases            -2876.1156
# Bush Advantage Collection Racetrack Conference Table                -1934.3976
# GBC DocuBind P400 Electric Binding System                           -1878.1662
# Cisco TelePresence System EX90 Videoconferencing Unit               -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener                  -1299.1836
# Balt Solid Wood Round Tables                                        -1201.0581
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables   -1148.4375
# Name: Profit, dtype: float64

# %% [markdown]
# 🚀 Task 11 — Discount Analysis

# %%
#Average Profit calculate karo.
d = df.groupby('Discount')['Profit'].mean()

# %%
#Highest discount level identify karo.
df['Discount'].max()
# Out:
# np.float64(0.8)

# %%
#Dekho kis discount level par average profit negative ho raha hai.
d[d<0]
# Out:
# Discount
# 0.30    -45.679636
# 0.32    -88.560656
# 0.40   -111.927429
# 0.45   -226.646464
# 0.50   -310.703456
# 0.60    -43.077212
# 0.70    -95.874060
# 0.80   -101.796797
# Name: Profit, dtype: float64

# %% [markdown]
# Task 12 — Quantity Analysis

# %%
df['Quantity'].agg(['mean','median','min','max','std'])
# Out:
# mean       3.789574
# median     3.000000
# min        1.000000
# max       14.000000
# std        2.225110
# Name: Quantity, dtype: float64

# %% [markdown]
# Task 13 — Date Analysis

# %%
df['Order Date'].head(5)
# Out:
# 0    11-08-2016
# 1    11-08-2016
# 2    06-12-2016
# 3    10-11-2015
# 4    10-11-2015
# Name: Order Date, dtype: object

# %%
df['Order Date'] = pd.to_datetime(
    df['Order Date'],
    format='mixed'
)
df['Order Date'].head()
# Out:
# 0   2016-11-08
# 1   2016-11-08
# 2   2016-06-12
# 3   2015-10-11
# 4   2015-10-11
# Name: Order Date, dtype: datetime64[ns]

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Year'] = df['Order Date'].dt.year
m = df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day
df[['Order Date', 'Year', 'Month', 'Day']].head()
# Out:
#   Order Date  Year  Month  Day
# 0 2016-11-08  2016     11    8
# 1 2016-11-08  2016     11    8
# 2 2016-06-12  2016      6   12
# 3 2015-10-11  2015     10   11
# 4 2015-10-11  2015     10   11

# %% [markdown]
# 🚀 Task 14 — Monthly Sales Analysis

# %%
#Find total Sales for each month.
m = df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
#Identify the month with the highest total Sales.
#Identify the month with the lowest total Sales.
m.idxmax()
m.idxmin()
# Out:
# 25

# %% [markdown]
# 🚀 Task 15 — Yearly Sales & Profit Analysis

# %%
#Har year ka total Sales find karo.
y = df.groupby('Year')['Sales'].sum()
#Har year ka total Profit find karo.
yy = df.groupby('Year')['Profit'].sum()
#Highest Sales wala year identify karo.
y.idxmax()
#Highest Profit wala year identify karo.
yy.idmax()

# %% [markdown]
# 🔥 Task 16 — Regional Sales & Profit Comparison

# %%
#Har Region ka total Sales find karo.
rs = df.groupby('Region')['Sales'].sum()
#Har Region ka total Profit find karo.
rp = df.groupby('Region')['Profit'].sum()
#Highest Sales wala Region identify karo.
rs.idxmax()
#Highest Profit wala Region identify karo.
rp.idxmax()
#Lowest Profit wala Region identify karo
rp.idxmin()
# Out:
# 'Central'

# %% [markdown]
# 🚀 Task 17 — Category × Region Analysis

# %%
#Find Total Sales for each combination of Region and Category.
rc = df.groupby(['Region','Category'])['Sales'].sum()
#Find the highest-selling Region–Category combination.
rc.idxmax()
# Out:
# ('East', 'Technology')

# %% [markdown]
# 🚀 Task 18 — Customer Analysis

# %%
#Find Top 10 customers by Total Sales.
tc = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending = False).head(10)
#Find Top 10 customers by Total Profit.
tp = df.groupby('Customer Name')['Profit'].sum().sort_values(ascending = False).head(10)
#Identify the customer with the highest total Sales.
tc = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending = False).head(1)

# %% [markdown]
# 🔥 Task 19 — Matplotlib Visualization

# %%
#Create a bar chart showing:
#Total Sales by Category
cs = df.groupby('Category')['Sales'].sum()
plt.bar(cs.index,cs.values)
plt.title("Sales by category")
plt.xlabel("category")
plt.ylabel("Total Sales")
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# Task 20 — Sales vs Profit Visualization

# %%
#Create a scatter plot to visualize the relationship between:
x = df['Sales']
y = df['Profit']
plt.scatter(x,y)
plt.title("Sales vs profit")
plt.xlabel('Sales')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')
